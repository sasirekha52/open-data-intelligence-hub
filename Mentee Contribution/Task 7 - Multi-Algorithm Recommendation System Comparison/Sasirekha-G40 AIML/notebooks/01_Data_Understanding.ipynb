# %%
pip install pandas numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
# Read the dataset using relative directory traversal paths
df = pd.read_csv(r"C:\Users\ELCOT\Desktop\Sasirekha-G40 AIML 7\data\SmartShop_Portfolio_Dataset.csv")

# %%
df.head()
# Out:
#    Interaction_ID  Customer_ID  Product_ID Category      Brand  Age  Gender  \
# 0               1       100001        4582    Books  PrimeGear   56    Male
# 1               2       100002        8527  Fashion  FreshMart   23  Female
# 2               3       100003        3677     Toys  FreshMart   35    Male
# 3               4       100004        5304  Grocery    EcoLife   43  Female
# 4               5       100005        6573  Fashion   BookNest   45    Male
#
#   Region Membership  Season  Holiday   Price  Discount  Views  Time_On_Page  \
# 0  South     Silver  Winter        0   47.27        10     16           479
# 1   East     Bronze  Summer        0  241.66        30     22            66
# 2   East       Gold  Spring        0  576.39        15     24            52
# 3  South       Gold  Summer        1  478.87        25     32           113
# 4   West     Silver  Spring        1  583.30        20     30           532
#
# ...

# %%
# Display structural rows from the trailing end of the frame
df.tail()
# Out:
#        Interaction_ID  Customer_ID  Product_ID Category      Brand  Age  \
# 14995           14996       114996        4424   Sports  FreshMart   61
# 14996           14997       114997        3925  Grocery  UrbanWear   53
# 14997           14998       114998        6884    Books    EcoLife   21
# 14998           14999       114999        8810     Toys   NovaTech   50
# 14999           15000       115000        4764     Toys   BookNest   31
#
#        Gender Region Membership  Season  Holiday    Price  Discount  Views  \
# 14995    Male   East     Bronze  Spring        0  1049.05         0      5
# 14996    Male  North     Silver  Autumn        0   542.43        20     34
# 14997    Male   East     Bronze  Winter        0   692.52         5     10
# 14998  Female   East     Silver  Spring        1    33.36        25      3
# 14999    Male   West     Bronze  Winter        0   498.67        10     23
#
#        Time_On_Page  Wishlist  Added_To_Cart  Previous_Purchases  \
# ...

# %%
print("Rows    :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows    : 15000
# Columns : 30

# %%
# List complete set of available schema headers
df.columns
# Out:
# Index(['Interaction_ID', 'Customer_ID', 'Product_ID', 'Category', 'Brand',
#        'Age', 'Gender', 'Region', 'Membership', 'Season', 'Holiday', 'Price',
#        'Discount', 'Views', 'Time_On_Page', 'Wishlist', 'Added_To_Cart',
#        'Previous_Purchases', 'Average_Order_Value', 'Days_Since_Last_Purchase',
#        'Recommendation_Score', 'Purchase_Status', 'Product_Rating',
#        'Customer_Lifetime_Value', 'Churn_Risk', 'Campaign_Response', 'Device',
#        'Payment_Method', 'Stock_Level', 'Delivery_Days'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Interaction_ID            15000 non-null  int64
#  1   Customer_ID               15000 non-null  int64
#  2   Product_ID                15000 non-null  int64
#  3   Category                  15000 non-null  object
#  4   Brand                     15000 non-null  object
#  5   Age                       15000 non-null  int64
#  6   Gender                    15000 non-null  object
#  7   Region                    15000 non-null  object
#  8   Membership                15000 non-null  object
#  9   Season                    15000 non-null  object
#  10  Holiday                   15000 non-null  int64
#  11  Price                     15000 non-null  float64
#  12  Discount                  15000 non-null  int64
# ...

# %%
missing = df.isnull().sum()

missing[missing > 0]
# Out:
# Series([], dtype: int64)

# %%
missing_percent = (df.isnull().sum()/len(df))*100

missing_percent.sort_values(ascending=False)
# Out:
# Interaction_ID              0.0
# Customer_ID                 0.0
# Product_ID                  0.0
# Category                    0.0
# Brand                       0.0
# Age                         0.0
# Gender                      0.0
# Region                      0.0
# Membership                  0.0
# Season                      0.0
# Holiday                     0.0
# Price                       0.0
# Discount                    0.0
# Views                       0.0
# Time_On_Page                0.0
# Wishlist                    0.0
# Added_To_Cart               0.0
# Previous_Purchases          0.0
# Average_Order_Value         0.0
# Days_Since_Last_Purchase    0.0
# Recommendation_Score        0.0
# Purchase_Status             0.0
# Product_Rating              0.0
# Customer_Lifetime_Value     0.0
# Churn_Risk                  0.0
# Campaign_Response           0.0
# Device                      0.0
# Payment_Method              0.0
# Stock_Level                 0.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Interaction_ID    Customer_ID    Product_ID           Age  \
# count    15000.000000   15000.000000  15000.000000  15000.000000
# mean      7500.500000  107500.500000   5530.472067     41.435400
# std       4330.271354    4330.271354   2599.804116     13.887573
# min          1.000000  100001.000000   1000.000000     18.000000
# 25%       3750.750000  103750.750000   3295.750000     29.000000
# 50%       7500.500000  107500.500000   5573.000000     41.000000
# 75%      11250.250000  111250.250000   7783.000000     53.000000
# max      15000.000000  115000.000000   9998.000000     65.000000
#
#             Holiday         Price      Discount         Views  Time_On_Page  \
# count  15000.000000  15000.000000  15000.000000  15000.000000  15000.000000
# mean       0.499000    755.776302     14.895667     20.611200    308.111067
# std        0.500016    427.023258     10.029996     11.501475    167.260042
# ...

# %%
df.describe(include="all")
# Out:
#         Interaction_ID    Customer_ID    Product_ID Category       Brand  \
# count     15000.000000   15000.000000  15000.000000    15000       15000
# unique             NaN            NaN           NaN        8          10
# top                NaN            NaN           NaN     Toys  KitchenPro
# freq               NaN            NaN           NaN     1918        1576
# mean       7500.500000  107500.500000   5530.472067      NaN         NaN
# std        4330.271354    4330.271354   2599.804116      NaN         NaN
# min           1.000000  100001.000000   1000.000000      NaN         NaN
# 25%        3750.750000  103750.750000   3295.750000      NaN         NaN
# 50%        7500.500000  107500.500000   5573.000000      NaN         NaN
# 75%       11250.250000  111250.250000   7783.000000      NaN         NaN
# max       15000.000000  115000.000000   9998.000000      NaN         NaN
#
#                  Age  Gender Region Membership  Season       Holiday  \
# ...

# %%
df.nunique()
# Out:
# Interaction_ID              15000
# Customer_ID                 15000
# Product_ID                   7274
# Category                        8
# Brand                          10
# Age                            48
# Gender                          2
# Region                          4
# Membership                      4
# Season                          4
# Holiday                         2
# Price                       14258
# Discount                        7
# Views                          40
# Time_On_Page                  581
# Wishlist                        2
# Added_To_Cart                   2
# Previous_Purchases             30
# Average_Order_Value         14179
# Days_Since_Last_Purchase      365
# Recommendation_Score           78
# Purchase_Status                 2
# Product_Rating                 26
# Customer_Lifetime_Value     14875
# Churn_Risk                     79
# Campaign_Response               2
# Device                          3
# ...

# %%
df["Category"].value_counts()
# Out:
# Category
# Toys           1918
# Sports         1897
# Beauty         1890
# Home           1888
# Grocery        1878
# Electronics    1859
# Books          1846
# Fashion        1824
# Name: count, dtype: int64

# %%
df["Brand"].value_counts()

df["Membership"].value_counts()

df["Device"].value_counts()

df["Payment_Method"].value_counts()
# Out:
# Payment_Method
# Wallet    3846
# COD       3747
# UPI       3722
# Card      3685
# Name: count, dtype: int64

# %%
report = pd.DataFrame({
    "Data Type": df.dtypes,
    "Missing Values": df.isnull().sum(),
    "Unique Values": df.nunique()
})

# %%
report
# Out:
#                          Data Type  Missing Values  Unique Values
# Interaction_ID               int64               0          15000
# Customer_ID                  int64               0          15000
# Product_ID                   int64               0           7274
# Category                    object               0              8
# Brand                       object               0             10
# Age                          int64               0             48
# Gender                      object               0              2
# Region                      object               0              4
# Membership                  object               0              4
# Season                      object               0              4
# Holiday                      int64               0              2
# Price                      float64               0          14258
# Discount                     int64               0              7
# ...

# %%
report.to_csv(r"C:\Users\ELCOT\Desktop\Sasirekha-G40 AIML 7\outputs\figures\reports\Data_Quality_Report.csv", index=False)

# %% [markdown]
# The dataset contains customer interaction records from an e-commerce platform.
# Both numerical and categorical variables are present.
# Product_Rating is the target for regression.
# Purchase_Status is the target for classification.
# Customer behavior features can be used for K-Means clustering.
# Data quality has been assessed by checking missing values, duplicates, and data types.
